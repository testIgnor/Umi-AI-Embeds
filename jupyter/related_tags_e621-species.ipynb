# %%
import json
import urllib.request
from urllib.error import HTTPError
import time
import math

# %%
franchise = 'digimon'
franchise_name = 'Digimon'
page_limit = 25

franchises_file = '../wildcards/Franchises.yaml'
franchises_text = """
'<[model][pony]>source_furry, _=Species/${FRANCHISE}=_':
  Description:
    - ${FRANCHISE} Characters
  Tags:
    - Myspecies
    - ${FRANCHISE}
"""
characterFile = f'../wildcards/species/{franchise_name}.txt'

# %%
def myurlopen(url, max_wait=300):
    i = 2
    while True:
        try:
            req = urllib.request.Request(
                                            url,
                                            data=None,
                                            headers={
                                                'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:108.0) Gecko/20100101 Firefox/108.0'
                                            }
                                        )
            r = urllib.request.urlopen(req)
            return r
        except HTTPError as e:
            print(e)
            sleep_time = 2 + 2**i / 1000
            if sleep_time > max_wait:
                print('ABORT!')
                raise TimeoutError(f'Timed out with max wait time of {max_wait} s')
            print(f'Some HTTP error occurred. Waiting for {sleep_time}...')
            time.sleep(sleep_time)
            i += 1
            continue


def cosine_similarity(tag1_count, tag2_count, tag12_count):
    return tag12_count / math.sqrt(tag1_count * tag2_count)

def get_e621_count(search_string):
    url = f"https://search.yiff.today/count?query={search_string}"
    print(f'now working on url: {url}')
    response = myurlopen(url)
    return json.loads(response.read())['count']

def get_similarity(tag1, tag2):
    tag1_count = get_e621_count(tag1)
    #tag2_count = get_e621_count(tag2)
    combined_count = get_e621_count(f'{tag1}+{tag2}')
    #return cosine_similarity(tag1_count, tag2_count, combined_count)
    return combined_count / tag1_count

# %%
jdata = []
for page in range(1, page_limit):
    url = f"https://e621.net/posts.json?limit=320&tags={franchise}&page={page}"
    print(f'now working on url: {url}')
    response = myurlopen(url)
    rjson = json.loads(response.read())
    if not rjson['posts']:
        break
    jdata += rjson['posts']
    time.sleep(1)
# Out:
# now working on url: https://e621.net/posts.json?limit=320&tags=digimon&page=1
# now working on url: https://e621.net/posts.json?limit=320&tags=digimon&page=2
# now working on url: https://e621.net/posts.json?limit=320&tags=digimon&page=3
# now working on url: https://e621.net/posts.json?limit=320&tags=digimon&page=4
# now working on url: https://e621.net/posts.json?limit=320&tags=digimon&page=5
# now working on url: https://e621.net/posts.json?limit=320&tags=digimon&page=6
# now working on url: https://e621.net/posts.json?limit=320&tags=digimon&page=7
# now working on url: https://e621.net/posts.json?limit=320&tags=digimon&page=8
# now working on url: https://e621.net/posts.json?limit=320&tags=digimon&page=9
# now working on url: https://e621.net/posts.json?limit=320&tags=digimon&page=10
# now working on url: https://e621.net/posts.json?limit=320&tags=digimon&page=11
# now working on url: https://e621.net/posts.json?limit=320&tags=digimon&page=12
# now working on url: https://e621.net/posts.json?limit=320&tags=digimon&page=13
# now working on url: https://e621.net/posts.json?limit=320&tags=digimon&page=14
# now working on url: https://e621.net/posts.json?limit=320&tags=digimon&page=15
# now working on url: https://e621.net/posts.json?limit=320&tags=digimon&page=16
# now working on url: https://e621.net/posts.json?limit=320&tags=digimon&page=17
# now working on url: https://e621.net/posts.json?limit=320&tags=digimon&page=18
# now working on url: https://e621.net/posts.json?limit=320&tags=digimon&page=19
# now working on url: https://e621.net/posts.json?limit=320&tags=digimon&page=20
# now working on url: https://e621.net/posts.json?limit=320&tags=digimon&page=21
# now working on url: https://e621.net/posts.json?limit=320&tags=digimon&page=22
# now working on url: https://e621.net/posts.json?limit=320&tags=digimon&page=23
# now working on url: https://e621.net/posts.json?limit=320&tags=digimon&page=24

# %%
character_tag_dict = {}

for post in jdata:
    post_tags = post['tags']
    characters = post_tags['species']

    for c in characters:
        if c in character_tag_dict.keys():
            character_tag_dict[c] += 1
        else:
            character_tag_dict[c] = 1

# %%
franchise_overlap_threshold = 0.9
total_post_threshold = 100

# %%
filtered_dict = {}

for c in character_tag_dict.keys():
    if character_tag_dict[c] < total_post_threshold:
        continue
    filtered_dict[c] = character_tag_dict[c]

# %%
accepted_characters = []

for c in filtered_dict.keys():
    similarity = get_similarity(c, franchise)
    if similarity < franchise_overlap_threshold:
        continue
    accepted_characters.append(c)
# Out:
# now working on url: https://search.yiff.today/count?query=digimon_(species)
# now working on url: https://search.yiff.today/count?query=digimon_(species)+digimon
# now working on url: https://search.yiff.today/count?query=renamon
# now working on url: https://search.yiff.today/count?query=renamon+digimon
# now working on url: https://search.yiff.today/count?query=gatomon
# now working on url: https://search.yiff.today/count?query=gatomon+digimon
# now working on url: https://search.yiff.today/count?query=generation_1_pokemon
# now working on url: https://search.yiff.today/count?query=generation_1_pokemon+digimon
# now working on url: https://search.yiff.today/count?query=pokemon_(species)
# now working on url: https://search.yiff.today/count?query=pokemon_(species)+digimon
# now working on url: https://search.yiff.today/count?query=guilmon
# now working on url: https://search.yiff.today/count?query=guilmon+digimon
# now working on url: https://search.yiff.today/count?query=human
# now working on url: https://search.yiff.today/count?query=human+digimon
# now working on url: https://search.yiff.today/count?query=mammal
# now working on url: https://search.yiff.today/count?query=mammal+digimon
# now working on url: https://search.yiff.today/count?query=flamedramon
# now working on url: https://search.yiff.today/count?query=flamedramon+digimon
# now working on url: https://search.yiff.today/count?query=canid
# now working on url: https://search.yiff.today/count?query=canid+digimon
# now working on url: https://search.yiff.today/count?query=canine
# now working on url: https://search.yiff.today/count?query=canine+digimon
# now working on url: https://search.yiff.today/count?query=canis
# now working on url: https://search.yiff.today/count?query=canis+digimon
# now working on url: https://search.yiff.today/count?query=domestic_dog
# now working on url: https://search.yiff.today/count?query=domestic_dog+digimon
# now working on url: https://search.yiff.today/count?query=reptile
# now working on url: https://search.yiff.today/count?query=reptile+digimon
# now working on url: https://search.yiff.today/count?query=scalie
# now working on url: https://search.yiff.today/count?query=scalie+digimon
# now working on url: https://search.yiff.today/count?query=gomamon
# now working on url: https://search.yiff.today/count?query=gomamon+digimon
# now working on url: https://search.yiff.today/count?query=veemon
# now working on url: https://search.yiff.today/count?query=veemon+digimon
# now working on url: https://search.yiff.today/count?query=gulusgammamon
# now working on url: https://search.yiff.today/count?query=gulusgammamon+digimon
# now working on url: https://search.yiff.today/count?query=gammamon
# now working on url: https://search.yiff.today/count?query=gammamon+digimon
# now working on url: https://search.yiff.today/count?query=dorumon
# now working on url: https://search.yiff.today/count?query=dorumon+digimon
# now working on url: https://search.yiff.today/count?query=dragon
# now working on url: https://search.yiff.today/count?query=dragon+digimon
# now working on url: https://search.yiff.today/count?query=mythological_creature
# now working on url: https://search.yiff.today/count?query=mythological_creature+digimon
# now working on url: https://search.yiff.today/count?query=mythological_scalie
# now working on url: https://search.yiff.today/count?query=mythological_scalie+digimon
# now working on url: https://search.yiff.today/count?query=x-digimon
# now working on url: https://search.yiff.today/count?query=x-digimon+digimon
# now working on url: https://search.yiff.today/count?query=domestic_cat
# now working on url: https://search.yiff.today/count?query=domestic_cat+digimon
# now working on url: https://search.yiff.today/count?query=felid
# now working on url: https://search.yiff.today/count?query=felid+digimon
# now working on url: https://search.yiff.today/count?query=feline
# now working on url: https://search.yiff.today/count?query=feline+digimon
# now working on url: https://search.yiff.today/count?query=felis
# now working on url: https://search.yiff.today/count?query=felis+digimon
# now working on url: https://search.yiff.today/count?query=fox
# now working on url: https://search.yiff.today/count?query=fox+digimon
# now working on url: https://search.yiff.today/count?query=hybrid
# now working on url: https://search.yiff.today/count?query=hybrid+digimon
# now working on url: https://search.yiff.today/count?query=marine
# now working on url: https://search.yiff.today/count?query=marine+digimon
# now working on url: https://search.yiff.today/count?query=impmon
# now working on url: https://search.yiff.today/count?query=impmon+digimon
# now working on url: https://search.yiff.today/count?query=wolf
# now working on url: https://search.yiff.today/count?query=wolf+digimon
# now working on url: https://search.yiff.today/count?query=dinosaur
# now working on url: https://search.yiff.today/count?query=dinosaur+digimon
# now working on url: https://search.yiff.today/count?query=prehistoric_species
# now working on url: https://search.yiff.today/count?query=prehistoric_species+digimon
# now working on url: https://search.yiff.today/count?query=lagomorph
# now working on url: https://search.yiff.today/count?query=lagomorph+digimon
# now working on url: https://search.yiff.today/count?query=leporid
# now working on url: https://search.yiff.today/count?query=leporid+digimon
# now working on url: https://search.yiff.today/count?query=rabbit
# now working on url: https://search.yiff.today/count?query=rabbit+digimon
# now working on url: https://search.yiff.today/count?query=weregarurumon
# now working on url: https://search.yiff.today/count?query=weregarurumon+digimon
# now working on url: https://search.yiff.today/count?query=generation_4_pokemon
# now working on url: https://search.yiff.today/count?query=generation_4_pokemon+digimon
# now working on url: https://search.yiff.today/count?query=lucario
# now working on url: https://search.yiff.today/count?query=lucario+digimon
# now working on url: https://search.yiff.today/count?query=taomon
# now working on url: https://search.yiff.today/count?query=taomon+digimon
# now working on url: https://search.yiff.today/count?query=humanoid
# now working on url: https://search.yiff.today/count?query=humanoid+digimon
# now working on url: https://search.yiff.today/count?query=exveemon
# now working on url: https://search.yiff.today/count?query=exveemon+digimon
# now working on url: https://search.yiff.today/count?query=wargreymon
# now working on url: https://search.yiff.today/count?query=wargreymon+digimon
# now working on url: https://search.yiff.today/count?query=symbareangoramon
# now working on url: https://search.yiff.today/count?query=symbareangoramon+digimon
# now working on url: https://search.yiff.today/count?query=animal_humanoid
# now working on url: https://search.yiff.today/count?query=animal_humanoid+digimon
# now working on url: https://search.yiff.today/count?query=imp
# now working on url: https://search.yiff.today/count?query=imp+digimon
# now working on url: https://search.yiff.today/count?query=demon
# now working on url: https://search.yiff.today/count?query=demon+digimon
# now working on url: https://search.yiff.today/count?query=angoramon
# now working on url: https://search.yiff.today/count?query=angoramon+digimon
# now working on url: https://search.yiff.today/count?query=gabumon
# now working on url: https://search.yiff.today/count?query=gabumon+digimon
# now working on url: https://search.yiff.today/count?query=leomon
# now working on url: https://search.yiff.today/count?query=leomon+digimon
# now working on url: https://search.yiff.today/count?query=avian
# now working on url: https://search.yiff.today/count?query=avian+digimon

# %%
accepted_characters
# Out:
# ['digimon_(species)',
#  'renamon',
#  'gatomon',
#  'guilmon',
#  'flamedramon',
#  'gomamon',
#  'veemon',
#  'gulusgammamon',
#  'gammamon',
#  'dorumon',
#  'x-digimon',
#  'impmon',
#  'weregarurumon',
#  'taomon',
#  'exveemon',
#  'wargreymon',
#  'symbareangoramon',
#  'angoramon',
#  'gabumon',
#  'leomon']

# %%
characters = []

for c in accepted_characters:

    character = c.strip().replace('_', ' ').replace('(', '\\(').replace(')', '\\)')
    the_franchise = franchise.strip().replace('_', ' ').replace('(', '\\(').replace(')', '\\)')
    final_string = f'({character}:1.3), {the_franchise}\n'
    characters.append(final_string)

# %%
if len(characters) > 0:
    with open(characterFile, 'a+') as f:
        f.writelines( characters )
    with open(franchises_file, 'a+') as f:
        new_text = franchises_text.replace('${FRANCHISE}', franchise_name)
        f.write(new_text)
