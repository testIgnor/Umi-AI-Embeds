# %%
import json
import urllib.request
from urllib.error import HTTPError
import time
import math

# %%
franchise = 'japanese_mythology'
franchise_name = 'Mythology'
page_limit = 25

franchises_file = '../wildcards/Franchises.yaml'
franchises_text = """
'<[model][pony]>source_furry, __Species/${FRANCHISE}__':
  Description:
    - ${FRANCHISE} Characters
  Tags:
    - Myspecies
    - ${FRANCHISE}
"""
characterFile = f'../wildcards/species/{franchise_name}.txt'

# %%
def myurlopen(url, max_wait=300):
    i = 2
    while True:
        try:
            req = urllib.request.Request(
                                            url,
                                            data=None,
                                            headers={
                                                'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:108.0) Gecko/20100101 Firefox/108.0'
                                            }
                                        )
            r = urllib.request.urlopen(req)
            return r
        except HTTPError as e:
            print(e)
            sleep_time = 2 + 2**i / 1000
            if sleep_time > max_wait:
                print('ABORT!')
                raise TimeoutError(f'Timed out with max wait time of {max_wait} s')
            print(f'Some HTTP error occurred. Waiting for {sleep_time}...')
            time.sleep(sleep_time)
            i += 1
            continue


def cosine_similarity(tag1_count, tag2_count, tag12_count):
    return tag12_count / math.sqrt(tag1_count * tag2_count)

def get_e621_count(search_string):
    url = f"https://search.yiff.today/count?query={search_string}"
    print(f'now working on url: {url}')
    response = myurlopen(url)
    return json.loads(response.read())['count']

def get_similarity(tag1, tag2):
    tag1_count = get_e621_count(tag1)
    #tag2_count = get_e621_count(tag2)
    combined_count = get_e621_count(f'{tag1}+{tag2}')
    #return cosine_similarity(tag1_count, tag2_count, combined_count)
    return combined_count / tag1_count

# %%
jdata = []
for page in range(1, page_limit):
    url = f"https://e621.net/posts.json?limit=320&tags={franchise}&page={page}"
    print(f'now working on url: {url}')
    response = myurlopen(url)
    rjson = json.loads(response.read())
    if not rjson['posts']:
        break
    jdata += rjson['posts']
    time.sleep(1)
# Out:
# now working on url: https://e621.net/posts.json?limit=320&tags=japanese_mythology&page=1
# now working on url: https://e621.net/posts.json?limit=320&tags=japanese_mythology&page=2
# now working on url: https://e621.net/posts.json?limit=320&tags=japanese_mythology&page=3
# now working on url: https://e621.net/posts.json?limit=320&tags=japanese_mythology&page=4
# now working on url: https://e621.net/posts.json?limit=320&tags=japanese_mythology&page=5
# now working on url: https://e621.net/posts.json?limit=320&tags=japanese_mythology&page=6
# now working on url: https://e621.net/posts.json?limit=320&tags=japanese_mythology&page=7
# now working on url: https://e621.net/posts.json?limit=320&tags=japanese_mythology&page=8
# now working on url: https://e621.net/posts.json?limit=320&tags=japanese_mythology&page=9
# now working on url: https://e621.net/posts.json?limit=320&tags=japanese_mythology&page=10
# now working on url: https://e621.net/posts.json?limit=320&tags=japanese_mythology&page=11
# now working on url: https://e621.net/posts.json?limit=320&tags=japanese_mythology&page=12
# now working on url: https://e621.net/posts.json?limit=320&tags=japanese_mythology&page=13
# now working on url: https://e621.net/posts.json?limit=320&tags=japanese_mythology&page=14
# now working on url: https://e621.net/posts.json?limit=320&tags=japanese_mythology&page=15
# now working on url: https://e621.net/posts.json?limit=320&tags=japanese_mythology&page=16
# now working on url: https://e621.net/posts.json?limit=320&tags=japanese_mythology&page=17
# now working on url: https://e621.net/posts.json?limit=320&tags=japanese_mythology&page=18
# now working on url: https://e621.net/posts.json?limit=320&tags=japanese_mythology&page=19
# now working on url: https://e621.net/posts.json?limit=320&tags=japanese_mythology&page=20
# now working on url: https://e621.net/posts.json?limit=320&tags=japanese_mythology&page=21
# now working on url: https://e621.net/posts.json?limit=320&tags=japanese_mythology&page=22
# now working on url: https://e621.net/posts.json?limit=320&tags=japanese_mythology&page=23
# now working on url: https://e621.net/posts.json?limit=320&tags=japanese_mythology&page=24

# %%
character_tag_dict = {}

for post in jdata:
    post_tags = post['tags']
    characters = post_tags['species']

    for c in characters:
        if c in character_tag_dict.keys():
            character_tag_dict[c] += 1
        else:
            character_tag_dict[c] = 1

# %%
franchise_overlap_threshold = 0.9
total_post_threshold = 100

# %%
filtered_dict = {}

for c in character_tag_dict.keys():
    if character_tag_dict[c] < total_post_threshold:
        continue
    filtered_dict[c] = character_tag_dict[c]

# %%
accepted_characters = []

for c in filtered_dict.keys():
    similarity = get_similarity(c, franchise)
    if similarity < franchise_overlap_threshold:
        continue
    accepted_characters.append(c)
# Out:
# now working on url: https://search.yiff.today/count?query=bear
# now working on url: https://search.yiff.today/count?query=bear+japanese_mythology
# now working on url: https://search.yiff.today/count?query=foo_dog
# now working on url: https://search.yiff.today/count?query=foo_dog+japanese_mythology
# now working on url: https://search.yiff.today/count?query=komainu
# now working on url: https://search.yiff.today/count?query=komainu+japanese_mythology
# now working on url: https://search.yiff.today/count?query=mammal
# now working on url: https://search.yiff.today/count?query=mammal+japanese_mythology
# now working on url: https://search.yiff.today/count?query=yokai
# now working on url: https://search.yiff.today/count?query=yokai+japanese_mythology
# now working on url: https://search.yiff.today/count?query=canid
# now working on url: https://search.yiff.today/count?query=canid+japanese_mythology
# now working on url: https://search.yiff.today/count?query=canine
# now working on url: https://search.yiff.today/count?query=canine+japanese_mythology
# now working on url: https://search.yiff.today/count?query=demon
# now working on url: https://search.yiff.today/count?query=demon+japanese_mythology
# now working on url: https://search.yiff.today/count?query=horned_humanoid
# now working on url: https://search.yiff.today/count?query=horned_humanoid+japanese_mythology
# now working on url: https://search.yiff.today/count?query=humanoid
# now working on url: https://search.yiff.today/count?query=humanoid+japanese_mythology
# now working on url: https://search.yiff.today/count?query=mythological_creature
# now working on url: https://search.yiff.today/count?query=mythological_creature+japanese_mythology
# now working on url: https://search.yiff.today/count?query=oni
# now working on url: https://search.yiff.today/count?query=oni+japanese_mythology
# now working on url: https://search.yiff.today/count?query=canis
# now working on url: https://search.yiff.today/count?query=canis+japanese_mythology
# now working on url: https://search.yiff.today/count?query=domestic_dog
# now working on url: https://search.yiff.today/count?query=domestic_dog+japanese_mythology
# now working on url: https://search.yiff.today/count?query=domestic_cat
# now working on url: https://search.yiff.today/count?query=domestic_cat+japanese_mythology
# now working on url: https://search.yiff.today/count?query=felid
# now working on url: https://search.yiff.today/count?query=felid+japanese_mythology
# now working on url: https://search.yiff.today/count?query=feline
# now working on url: https://search.yiff.today/count?query=feline+japanese_mythology
# now working on url: https://search.yiff.today/count?query=felis
# now working on url: https://search.yiff.today/count?query=felis+japanese_mythology
# now working on url: https://search.yiff.today/count?query=hybrid
# now working on url: https://search.yiff.today/count?query=hybrid+japanese_mythology
# now working on url: https://search.yiff.today/count?query=fox
# now working on url: https://search.yiff.today/count?query=fox+japanese_mythology
# now working on url: https://search.yiff.today/count?query=fox_spirit
# now working on url: https://search.yiff.today/count?query=fox_spirit+japanese_mythology
# now working on url: https://search.yiff.today/count?query=reptile
# now working on url: https://search.yiff.today/count?query=reptile+japanese_mythology
# now working on url: https://search.yiff.today/count?query=scalie
# now working on url: https://search.yiff.today/count?query=scalie+japanese_mythology
# now working on url: https://search.yiff.today/count?query=animal_humanoid
# now working on url: https://search.yiff.today/count?query=animal_humanoid+japanese_mythology
# now working on url: https://search.yiff.today/count?query=arthropod
# now working on url: https://search.yiff.today/count?query=arthropod+japanese_mythology
# now working on url: https://search.yiff.today/count?query=bovid
# now working on url: https://search.yiff.today/count?query=bovid+japanese_mythology
# now working on url: https://search.yiff.today/count?query=bovine
# now working on url: https://search.yiff.today/count?query=bovine+japanese_mythology
# now working on url: https://search.yiff.today/count?query=human
# now working on url: https://search.yiff.today/count?query=human+japanese_mythology
# now working on url: https://search.yiff.today/count?query=kappa
# now working on url: https://search.yiff.today/count?query=kappa+japanese_mythology
# now working on url: https://search.yiff.today/count?query=mammal_humanoid
# now working on url: https://search.yiff.today/count?query=mammal_humanoid+japanese_mythology
# now working on url: https://search.yiff.today/count?query=nekomata
# now working on url: https://search.yiff.today/count?query=nekomata+japanese_mythology
# now working on url: https://search.yiff.today/count?query=avian
# now working on url: https://search.yiff.today/count?query=avian+japanese_mythology
# now working on url: https://search.yiff.today/count?query=bird
# now working on url: https://search.yiff.today/count?query=bird+japanese_mythology
# now working on url: https://search.yiff.today/count?query=marine
# now working on url: https://search.yiff.today/count?query=marine+japanese_mythology
# now working on url: https://search.yiff.today/count?query=canid_humanoid
# now working on url: https://search.yiff.today/count?query=canid_humanoid+japanese_mythology
# now working on url: https://search.yiff.today/count?query=canine_humanoid
# now working on url: https://search.yiff.today/count?query=canine_humanoid+japanese_mythology
# now working on url: https://search.yiff.today/count?query=demon_humanoid
# now working on url: https://search.yiff.today/count?query=demon_humanoid+japanese_mythology
# now working on url: https://search.yiff.today/count?query=fox_humanoid
# now working on url: https://search.yiff.today/count?query=fox_humanoid+japanese_mythology
# now working on url: https://search.yiff.today/count?query=ghost
# now working on url: https://search.yiff.today/count?query=ghost+japanese_mythology
# now working on url: https://search.yiff.today/count?query=monster
# now working on url: https://search.yiff.today/count?query=monster+japanese_mythology
# now working on url: https://search.yiff.today/count?query=spirit
# now working on url: https://search.yiff.today/count?query=spirit+japanese_mythology
# now working on url: https://search.yiff.today/count?query=wolf
# now working on url: https://search.yiff.today/count?query=wolf+japanese_mythology
# now working on url: https://search.yiff.today/count?query=digimon_(species)
# now working on url: https://search.yiff.today/count?query=digimon_(species)+japanese_mythology
# now working on url: https://search.yiff.today/count?query=raccoon_dog
# now working on url: https://search.yiff.today/count?query=raccoon_dog+japanese_mythology
# now working on url: https://search.yiff.today/count?query=tanuki
# now working on url: https://search.yiff.today/count?query=tanuki+japanese_mythology
# now working on url: https://search.yiff.today/count?query=kamaitachi
# now working on url: https://search.yiff.today/count?query=kamaitachi+japanese_mythology
# now working on url: https://search.yiff.today/count?query=mustelid
# now working on url: https://search.yiff.today/count?query=mustelid+japanese_mythology
# now working on url: https://search.yiff.today/count?query=bakeneko
# now working on url: https://search.yiff.today/count?query=bakeneko+japanese_mythology
# now working on url: https://search.yiff.today/count?query=avian_humanoid
# now working on url: https://search.yiff.today/count?query=avian_humanoid+japanese_mythology
# now working on url: https://search.yiff.today/count?query=cat_humanoid
# now working on url: https://search.yiff.today/count?query=cat_humanoid+japanese_mythology
# now working on url: https://search.yiff.today/count?query=dragon
# now working on url: https://search.yiff.today/count?query=dragon+japanese_mythology
# now working on url: https://search.yiff.today/count?query=felid_humanoid
# now working on url: https://search.yiff.today/count?query=felid_humanoid+japanese_mythology
# now working on url: https://search.yiff.today/count?query=feline_humanoid
# now working on url: https://search.yiff.today/count?query=feline_humanoid+japanese_mythology
# now working on url: https://search.yiff.today/count?query=mythological_scalie
# now working on url: https://search.yiff.today/count?query=mythological_scalie+japanese_mythology
# now working on url: https://search.yiff.today/count?query=pantherine
# now working on url: https://search.yiff.today/count?query=pantherine+japanese_mythology
# now working on url: https://search.yiff.today/count?query=snake
# now working on url: https://search.yiff.today/count?query=snake+japanese_mythology
# now working on url: https://search.yiff.today/count?query=lagomorph
# now working on url: https://search.yiff.today/count?query=lagomorph+japanese_mythology
# now working on url: https://search.yiff.today/count?query=rodent
# now working on url: https://search.yiff.today/count?query=rodent+japanese_mythology
# now working on url: https://search.yiff.today/count?query=tengu
# now working on url: https://search.yiff.today/count?query=tengu+japanese_mythology
# now working on url: https://search.yiff.today/count?query=leporid
# now working on url: https://search.yiff.today/count?query=leporid+japanese_mythology
# now working on url: https://search.yiff.today/count?query=rabbit
# now working on url: https://search.yiff.today/count?query=rabbit+japanese_mythology
# now working on url: https://search.yiff.today/count?query=tiger
# now working on url: https://search.yiff.today/count?query=tiger+japanese_mythology
# now working on url: https://search.yiff.today/count?query=pokemon_(species)
# now working on url: https://search.yiff.today/count?query=pokemon_(species)+japanese_mythology

# %%
accepted_characters
# Out:
# ['komainu',
#  'yokai',
#  'oni',
#  'kappa',
#  'nekomata',
#  'kamaitachi',
#  'bakeneko',
#  'tengu']

# %%
characters = []

for c in accepted_characters:

    character = c.strip().replace('_', ' ').replace('(', '\\(').replace(')', '\\)')
    the_franchise = franchise.strip().replace('_', ' ').replace('(', '\\(').replace(')', '\\)')
    final_string = f'({character}:1.3), {the_franchise}\n'
    characters.append(final_string)

# %%
if len(characters) > 0:
    with open(characterFile, 'a+') as f:
        f.writelines( characters )
    with open(franchises_file, 'a+') as f:
        new_text = franchises_text.replace('${FRANCHISE}', franchise_name)
        f.write(new_text)
